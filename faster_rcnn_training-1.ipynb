# %% [markdown]
# ## Set environment

# %%
#Mount google drive when on google colab

from google.colab import drive
drive.mount('/content/drive')

#Set working directory on google colab
# %cd /content/drive/MyDrive/shape-recognition/

# %%
# Install packages
# %pip install -r requirements.txt

# %% [markdown]
# ## Training

# %%
# !wandb disabled
# %run train.py --name data-1 --epochs 10 --batch 2 --lr 0.001 --model fasterrcnn_resnet50_fpn_v2 --data configs/data-1.yaml --imgsz 1024 --no-mosaic --workers 2 --device cuda
# Out:
# W&B disabled.
# Not using distributed mode
# device cuda
# Creating data loaders
# Number of training samples: 1000
# Number of validation samples: 100
#
# Building model from scratch...
# 43,266,403 total parameters.
# 43,041,059 training parameters.
# [INFO/Process-3] child process calling self.run()
# [INFO/Process-4] child process calling self.run()
# [INFO/MainProcess] Epoch: [0]  [  0/500]  eta: 0:06:45  lr: 0.000003  loss: 4.7407 (4.7407)  loss_classifier: 1.4812 (1.4812)  loss_box_reg: 0.4122 (0.4122)  loss_objectness: 2.7358 (2.7358)  loss_rpn_box_reg: 0.1116 (0.1116)  time: 0.8107  data: 0.2613  max mem: 3309
# [INFO/MainProcess] Epoch: [0]  [100/500]  eta: 0:03:35  lr: 0.000203  loss: 1.6367 (2.6488)  loss_classifier: 0.7287 (0.9965)  loss_box_reg: 0.6974 (0.6737)  loss_objectness: 0.1436 (0.8955)  loss_rpn_box_reg: 0.0697 (0.0830)  time: 0.5424  data: 0.0099  max mem: 3563
# [INFO/Process-4] process shutting down
# [INFO/Process-4] process exiting with exitcode 0
# [INFO/Process-3] process shutting down
# [INFO/Process-3] process exiting with exitcode 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /content/drive/MyDrive/shape-recognition/train.py in <module>
#     540 if __name__ == '__main__':
#     541     args = parse_opt()
# --> 542     main(args)
#     543
#
# /content/drive/MyDrive/shape-recognition/train.py in main(args)
#     381             batch_loss_box_reg_list, \
#     382             batch_loss_objectness_list, \
# --> 383             batch_loss_rpn_list = train_one_epoch(
#     384             model,
#     385             optimizer,
#
# /content/drive/MyDrive/shape-recognition/torch_utils/engine.py in train_one_epoch(model, optimizer, data_loader, device, epoch, train_loss_hist, print_freq, scaler, scheduler)
#      50
#      51         with torch.cuda.amp.autocast(enabled=scaler is not None):
# ---> 52             loss_dict = model(images, targets)
#      53             losses = sum(loss for loss in loss_dict.values())
#      54
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/torchvision/models/detection/generalized_rcnn.py in forward(self, images, targets)
#     102         if isinstance(features, torch.Tensor):
#     103             features = OrderedDict([("0", features)])
# --> 104         proposals, proposal_losses = self.rpn(images, features, targets)
#     105         detections, detector_losses = self.roi_heads(features, proposals, images.image_sizes, targets)
#     106         detections = self.transform.postprocess(detections, images.image_sizes, original_image_sizes)  # type: ignore[operator]
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/torchvision/models/detection/rpn.py in forward(self, images, features, targets)
#     368         # note that we detach the deltas because Faster R-CNN do not backprop through
#     369         # the proposals
# --> 370         proposals = self.box_coder.decode(pred_bbox_deltas.detach(), anchors)
#     371         proposals = proposals.view(num_images, -1, 4)
#     372         boxes, scores = self.filter_proposals(proposals, objectness, images.image_sizes, num_anchors_per_level)
#
# /usr/local/lib/python3.10/dist-packages/torchvision/models/detection/_utils.py in decode(self, rel_codes, boxes)
#     176         if box_sum > 0:
#     177             rel_codes = rel_codes.reshape(box_sum, -1)
# --> 178         pred_boxes = self.decode_single(rel_codes, concat_boxes)
#     179         if box_sum > 0:
#     180             pred_boxes = pred_boxes.reshape(box_sum, -1, 4)
#
# /usr/local/lib/python3.10/dist-packages/torchvision/models/detection/_utils.py in decode_single(self, rel_codes, boxes)
#     214
#     215         # Distance from center to box's corner.
# --> 216         c_to_c_h = torch.tensor(0.5, dtype=pred_ctr_y.dtype, device=pred_h.device) * pred_h
#     217         c_to_c_w = torch.tensor(0.5, dtype=pred_ctr_x.dtype, device=pred_w.device) * pred_w
#     218
#
# KeyboardInterrupt:

# %%
#%run train.py --resume-training --name data-1 --epochs 20 --batch 2 --lr 0.001 --model fasterrcnn_resnet50_fpn_v2 --weights outputs/training/data-1/last_model.pth --data configs/data-1.yaml --imgsz 1024 --no-mosaic --workers 2 --device cuda

# %% [markdown]
# ## Visualize Object Detection Results

# %%
# %run detect.py --threshold 0.3 --input data/test-1 --num-images 4 --show --no-labels --weights outputs/training/data-1/best_model.pth --data configs/data-1.yaml --model fasterrcnn_resnet50_fpn_v2 --device cuda --imgsz 1024

# %% [markdown]
# ## Evaluation on Test Data

# %%
# %run eval.py --data configs/data-3.yaml --weights outputs/training/data-1/best_model.pth --model fasterrcnn_resnet50_fpn_v2 --batch 4 --workers 2 --device cuda --imgsz 1024
# %run eval.py --data configs/data-2.yaml --weights outputs/training/data-1/best_model.pth --model fasterrcnn_resnet50_fpn_v2 --batch 4 --workers 2 --device cuda --imgsz 1024
# %run eval.py --data configs/data-1.yaml --weights outputs/training/data-1/best_model.pth --model fasterrcnn_resnet50_fpn_v2 --batch 4 --workers 2 --device cuda --imgsz 1024
# %run eval.py --data configs/data-0.yaml --weights outputs/training/data-1/best_model.pth --model fasterrcnn_resnet50_fpn_v2 --batch 4 --workers 2 --device cuda --imgsz 1024
