# %% [markdown]
# ## Set environment

# %%
#Mount google drive when on google colab

from google.colab import drive
drive.mount('/content/drive')

#Set working directory on google colab
# %cd /content/drive/MyDrive/shape-recognition/

# %%
# Install packages
# %pip install -r requirements.txt

import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Training

# %%
# !wandb disabled
# %run train.py --name data-1 --epochs 15 --batch 2 --lr 0.001 --model fasterrcnn_resnet50_fpn_v2 --data configs/data-1.yaml --imgsz 1024 --no-mosaic --workers 2 --device cuda
# Out:
# W&B disabled.
# Not using distributed mode
# device cuda
# Creating data loaders
# Number of training samples: 1000
# Number of validation samples: 100
#
# Building model from scratch...
# 43,266,403 total parameters.
# 43,041,059 training parameters.
# [INFO/Process-45] child process calling self.run()
# [INFO/Process-46] child process calling self.run()
# [INFO/MainProcess] Epoch: [0]  [  0/500]  eta: 0:09:07  lr: 0.000003  loss: 4.7407 (4.7407)  loss_classifier: 1.4812 (1.4812)  loss_box_reg: 0.4122 (0.4122)  loss_objectness: 2.7358 (2.7358)  loss_rpn_box_reg: 0.1116 (0.1116)  time: 1.0945  data: 0.4354  max mem: 5158
# [INFO/MainProcess] Epoch: [0]  [100/500]  eta: 0:03:57  lr: 0.000203  loss: 1.6456 (2.6527)  loss_classifier: 0.7289 (0.9967)  loss_box_reg: 0.6944 (0.6757)  loss_objectness: 0.1522 (0.8981)  loss_rpn_box_reg: 0.0685 (0.0823)  time: 0.5719  data: 0.0117  max mem: 5405
# ...

# %%
#%run train.py --resume-training --name data-1 --epochs 20 --batch 2 --lr 0.001 --model fasterrcnn_resnet50_fpn_v2 --weights outputs/training/data-1/last_model.pth --data configs/data-1.yaml --imgsz 1024 --no-mosaic --workers 2 --device cuda

# %% [markdown]
# ## Visualize Object Detection Results

# %%
# %run detect.py --threshold 0.3 --input data/test-1 --num-images 2 --output outputs/inference/data-1 --no-labels --weights outputs/training/data-1/best_model.pth --data configs/data-1.yaml --model fasterrcnn_resnet50_fpn_v2 --device cuda --imgsz 1024
# Out:
# data/test-1/test0000.jpg --> outputs/inference/data-1/test0000.jpg
# data/test-1/test0001.jpg --> outputs/inference/data-1/test0001.jpg

# %%
#show results

path = 'outputs/inference/data-1'
for i in range(2):
  file = f'{path}/test{i:04d}'
  print(file+'.jpg (csv)')
  plt.figure(figsize=(10,10))
  plt.imshow(plt.imread(file+'.jpg'))
  plt.axis('off')
  plt.show()
  display(pd.read_csv(file+'.csv'))
# Out:
# outputs/inference/data-1/test0000.jpg (csv)
#     class     score          x0          y0         x1          y1
# 0       2  0.999995  794.350500  325.269530  884.60350   415.66663
# 1       2  0.999995  857.757500  803.667800  952.16766   899.83563
# 2       2  0.999992  615.417240   63.051624  682.12787   130.55060
# 3       4  0.999990  333.747070  626.170840  391.37300   684.62335
# 4       2  0.999990   10.395810  786.789900  105.96985   881.34753
# 5       2  0.999989   23.623837  341.352260  117.51882   436.74445
# 6       2  0.999989   57.874190  771.673100  154.62970   868.51780
# 7       2  0.999989  297.729280   16.889072  395.04562   115.14731
# 8       2  0.999988  788.150800  567.649660  860.53210   642.44210
# 9       2  0.999987  752.578370  500.988160  833.34790   583.17145
# 10      3  0.999985  858.411000  600.314100  917.72430   656.54910
# 11      4  0.999984  230.968480  798.606900  311.41980   880.50433
# ...

# %% [markdown]
# ## Evaluation on Test Data

# %%
# %run eval.py --data configs/data-3.yaml --weights outputs/training/data-1/best_model.pth --model fasterrcnn_resnet50_fpn_v2 --batch 4 --workers 2 --device cuda --imgsz 1024
# %run eval.py --data configs/data-2.yaml --weights outputs/training/data-1/best_model.pth --model fasterrcnn_resnet50_fpn_v2 --batch 4 --workers 2 --device cuda --imgsz 1024
# %run eval.py --data configs/data-1.yaml --weights outputs/training/data-1/best_model.pth --model fasterrcnn_resnet50_fpn_v2 --batch 4 --workers 2 --device cuda --imgsz 1024
# %run eval.py --data configs/data-0.yaml --weights outputs/training/data-1/best_model.pth --model fasterrcnn_resnet50_fpn_v2 --batch 4 --workers 2 --device cuda --imgsz 1024
# Out:
# [INFO/Process-105] child process calling self.run()
# [INFO/Process-106] child process calling self.run()
# [INFO/MainProcess] Test:  [ 0/25]  eta: 0:01:29    time: 3.5619  data: 2.9438  max mem: 5405
# [INFO/MainProcess] Test:  [24/25]  eta: 0:00:01    time: 1.6526  data: 1.1327  max mem: 5405
# [INFO/Process-106] process shutting down
# [INFO/Process-105] process shutting down
# [INFO/Process-105] process exiting with exitcode 0
# [INFO/Process-106] process exiting with exitcode 0
# [INFO/MainProcess] Test: Total time: 0:00:43 (1.7337 s / it)
# Test data from configs/data-3.yaml
# ---------------------------------------------------------------
# | Class           | AP                  | AR                  |
# ---------------------------------------------------------------
# | 2               | 0.860               | 0.879               |
# | 3               | 0.528               | 0.718               |
# | 4               | 0.671               | 0.740               |
# ...
