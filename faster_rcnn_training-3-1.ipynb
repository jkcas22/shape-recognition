# %% [markdown]
# ## Set environment

# %%
#Mount google drive when on google colaboratory

from google.colab import drive
drive.mount('/content/drive')

# Enter the repo directory on google colaboratory.
# %cd /content/drive/MyDrive/shape-recognition/

# %%
# Install packages
# %pip install -r requirements.txt

# %% [markdown]
# ## Training

# %%
# !wandb disabled

# %%
# !python train.py --data configs/data-3.yaml --epochs 20 --batch 4 --lr 0.002 --model fasterrcnn_resnet50_fpn_v2 --name data-3-1 --workers 2 --no-mosaic --device cuda --imgsz 1024

# %% [markdown]
# ## Visualize Validation Results

# %%
import matplotlib.pyplot as plt
import glob as glob

# %%
results_dir_path = './outputs/training/data-3-1'
valid_images = glob.glob(f"{results_dir_path}/*.jpg")

for i in range(2):
    plt.figure(figsize=(10, 7))
    image = plt.imread(valid_images[i])
    plt.imshow(image)
    plt.axis('off')
    plt.show()

# %% [markdown]
# ## Evaluation

# %%
# Verbose mAP.
# !python eval.py --weights outputs/training/data-3-1/best_model.pth --data configs/data-3.yaml --model fasterrcnn_resnet50_fpn_v2 --batch 4 --workers 2 --verbose --imgsz 1024

# %% [markdown]
# ## Evaluation on other test data

# %%
# !python eval.py --weights outputs/training/data-3-1/best_model.pth --data configs/data-0.yaml --model fasterrcnn_resnet50_fpn_v2 --batch 4 --workers 2 --verbose --imgsz 1024

# %%
# !python eval.py --weights outputs/training/data-3-1/best_model.pth --data configs/data-1.yaml --model fasterrcnn_resnet50_fpn_v2 --batch 4 --workers 2 --verbose --imgsz 1024

# %%
# !python eval.py --weights outputs/training/data-3-1/best_model.pth --data configs/data-2.yaml --model fasterrcnn_resnet50_fpn_v2 --batch 4 --workers 2 --verbose --imgsz 1024
